# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Conv2D,
    MaxPooling2D,
    AveragePooling2D,
    Flatten,
    Dense,
    Dropout,
)
import pickle 
import numpy as np
import cv2
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
import pandas as pd
import seaborn as sns
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# Consruct emotion model, download and load weights (Emotion.py in Deepface)

# %%
input_dim_ = 64

# %%
num_classes = 2

model = Sequential()

# 1st convolution layer
model.add(Conv2D(64, (5, 5), activation="relu", input_shape=(input_dim_, input_dim_, 1)))
# model.add(Conv2D(32, (3, 3), activation="relu"))
model.add(MaxPooling2D(pool_size=(5, 5), strides=(2, 2)))

# 2nd convolution layer
# model.add(Conv2D(64, (3, 3), activation="relu"))
# model.add(Conv2D(64, (3, 3), activation="relu"))
# model.add(AveragePooling2D(pool_size=(3, 3), strides=(2, 2)))

# 3rd convolution layer
model.add(Conv2D(128, (3, 3), activation="relu"))
# model.add(Conv2D(128, (3, 3), activation="relu"))
model.add(AveragePooling2D(pool_size=(3, 3), strides=(2, 2)))

model.add(Flatten())

# fully connected neural networks
# model.add(Dense(1024, activation="relu"))
# model.add(Dropout(0.2))
# model.add(Dense(1024, activation="relu"))
# model.add(Dropout(0.2))

model.add(Dense(num_classes, activation="softmax"))
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Metal device set to: Apple M2
# 2024-08-23 23:42:47.898355: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-08-23 23:42:47.898481: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 60, 60, 64)        1664
#
#  max_pooling2d (MaxPooling2D  (None, 28, 28, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 26, 26, 128)       73856
#
#  average_pooling2d (AverageP  (None, 12, 12, 128)      0
#  ooling2D)
#
#  flatten (Flatten)           (None, 18432)             0
#
#  dense (Dense)               (None, 2)                 36866
#
# =================================================================
# Total params: 112,386
# Trainable params: 112,386
# Non-trainable params: 0
# _________________________________________________________________

# %%
# load pickle file
files = ['../data_features_labels/EA_annotated_3Blue1Brown_final.pkl']
# files = ['Eastern_Asian_Dataset.pkl']
x_train_list = []
y_train_list = [] 
for file in files:
    with open(file, 'rb') as f:
        features, labels = pickle.load(f)
    
    for pic, label in zip(features, labels):
        # plt.imshow(img_gray, cmap='binary_r')
        x_train_list.append(pic)
        y_train_list.append(label)

# %%
X_train = np.array(x_train_list).reshape(-1, input_dim_, input_dim_, 1)
#one-hot encode target column
Y_train = to_categorical(np.array(y_train_list))

# %%
Y_train[500].argmax()
# Out:
# 0

# %%
np.unique(Y_train.argmax(axis=1), return_counts=True)
# Out:
# (array([0, 1]), array([6324, 5323]))

# %%
indices = [np.where(Y_train.argmax(axis=1)==i)[0] for i in np.unique(Y_train.argmax(axis=1))]
indices
# Out:
# [array([    0,     1,     2, ..., 11644, 11645, 11646]),
#  array([  657,   658,   659, ..., 11623, 11624, 11625])]

# %%
label_names = ['Not Confused', 'Confused']
rows = 2
cols = 8
# num_to_choose = int(rows*cols)
# np.random.seed(42)
# chosen_nums = np.random.choice(np.arange(len(X_train)), size=num_to_choose, replace=False)
fig, ax = plt.subplots(rows, cols, figsize=(20, 5), sharex=True, sharey=True)

for row in range(rows):
    np.random.seed(35)
    # num_to_choose = int(rows*cols)
    chosen_nums = np.random.choice(indices[row], size=cols, replace=False)
    count = 0
    for col in range(cols):
        ax[row, col].imshow(X_train[chosen_nums[count]], cmap='binary_r')
        ax[row, col].text(32, 10, label_names[Y_train[chosen_nums[count]].argmax()], 
                          horizontalalignment='center', color='r')
        count += 1
        
        ax[row, col].axis('off')

# %%
x_train, x_test, y_train, y_test = train_test_split(X_train, Y_train, test_size=0.2, random_state=42)
# x_train, x_valid, y_train, y_valid = train_test_split(x_train, y_train, test_size=0.25, random_state=42)
x_train.shape, x_test.shape
# Out:
# ((9317, 64, 64, 1), (2330, 64, 64, 1))

# %%
model.fit(x_train, y_train, epochs=200)
# Out:
# 2024-08-23 23:43:56.703317: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2024-08-23 23:43:56.888016: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# Epoch
200
# 292/292 [==============================] - 9s 29ms/step - loss: 0.0358 - accuracy: 0.9866
# Epoch 160/200
# 292/292 [==============================] - 9s 30ms/step - loss: 0.0391 - accuracy: 0.9871
# Epoch 161/200
# 292/292 [==============================] - 9s 30ms/step - loss: 0.0321 - accuracy: 0.9899
# Epoch 162/200
# 292/292 [==============================] - 9s 29ms/step - loss: 0.0355 - accuracy: 0.9865
# Epoch 163/200
# 292/292 [==============================] - 9s 29ms/step - loss: 0.0451 - accuracy: 0.9843
# Epoch 164/200
# 292/292 [==============================] - 9s 29ms/step - loss: 0.0343 - accuracy: 0.9872
# Epoch 165/200
# 292/292 [==============================] - 9s 30ms/step - loss: 0.0459 - accuracy: 0.9843
# Epoch 166/200
# 292/292 [==============================] - 9s 29ms/step - loss: 0.0666 - accuracy: 0.9806
# Epoch 167/200
# 292/292 [==============================] - 9s 29ms/step - loss: 0.0441 - accuracy: 0.9848
# Epoch 168/200
# 292/292 [==============================] - 9s 30ms/step - loss: 0.0650 - accuracy: 0.9797
# Epoch 169/200
# 292/292 [==============================] - 9s 29ms/step - loss: 0.0409 - accuracy: 0.9881
# Epoch 170/200
# 292/292 [==============================] - 9s 29ms/step - loss: 0.0652 - accuracy: 0.9787
# Epoch 171/200
# 292/292 [==============================] - 9s 30ms/step - loss: 0.0297 - accuracy: 0.9884
# Epoch 172/200
# 292/292 [==============================] - 9s 30ms/step - loss: 0.0252 - accuracy: 0.9913
# Epoch 173/200
# 292/292 [==============================] - 9s 29ms/step - loss: 0.1153 - accuracy: 0.9653
# Epoch 174/200
# 292/292 [==============================] - 9s 30ms/step - loss: 0.0552 - accuracy: 0.9838
# Epoch 175/200
# 292/292 [==============================] - 9s 29ms/step - loss: 0.0465 - accuracy: 0.9848
# Epoch 176/200
# 292/292 [==============================] - 9s 29ms/step - loss: 0.0275 - accuracy: 0.9911
# Epoch 177/200
# 292/292 [==============================] - 9s 29ms/step - loss: 0.0195 - accuracy: 0.9927
# Epoch 178/200
# 292/292 [==============================] - 9s 30ms/step - loss: 0.0360 - accuracy: 0.9857
# Epoch 179/200
# 292/292 [==============================] - 9s 29ms/step - loss: 0.0671 - accuracy: 0.9804
# Epoch 180/200
# 292/292 [==============================] - 9s 29ms/step - loss: 0.0328 - accuracy: 0.9879
# Epoch 181/200
# 292/292 [==============================] - 9s 29ms/step - loss: 0.0437 - accuracy: 0.9850
# Epoch 182/200
# 292/292 [==============================] - 9s 30ms/step - loss: 0.0297 - accuracy: 0.9896
# Epoch 183/200
# 292/292 [==============================] - 9s 29ms/step - loss: 0.0176 - accuracy: 0.9933
# Epoch 184/200
# 292/292 [==============================] - 9s 29ms/step - loss: 0.0312 - accuracy: 0.9879
# Epoch 185/200
# 292/292 [==============================] - 9s 29ms/step - loss: 0.0540 - accuracy: 0.9801
# Epoch 186/200
# 292/292 [==============================] - 9s 30ms/step - loss: 0.0776 - accuracy: 0.9785
# Epoch 187/200
# 292/292 [==============================] - 9s 29ms/step - loss: 0.0257 - accuracy: 0.9911
# Epoch 188/200
# 292/292 [==============================] - 9s 29ms/step - loss: 0.0370 - accuracy: 0.9879
# Epoch 189/200
# 292/292 [==============================] - 9s 29ms/step - loss: 0.0393 - accuracy: 0.9858
# Epoch 190/200
# 292/292 [==============================] - 9s 30ms/step - loss: 0.0252 - accuracy: 0.9922
# Epoch 191/200
# 292/292 [==============================] - 9s 30ms/step - loss: 0.0645 - accuracy: 0.9882
# Epoch 192/200
# 292/292 [==============================] - 9s 30ms/step - loss: 0.1056 - accuracy: 0.9707
# Epoch 193/200
# 292/292 [==============================] - 9s 30ms/step - loss: 0.0530 - accuracy: 0.9827
# Epoch 194/200
# 292/292 [==============================] - 9s 29ms/step - loss: 0.0271 - accuracy: 0.9917
# Epoch 195/200
# 292/292 [==============================] - 9s 29ms/step - loss: 0.0309 - accuracy: 0.9877
# Epoch 196/200
# 292/292 [==============================] - 9s 30ms/step - loss: 0.0338 - accuracy: 0.9893
# Epoch 197/200
# 292/292 [==============================] - 9s 29ms/step - loss: 0.0506 - accuracy: 0.9851
# Epoch 198/200
# 292/292 [==============================] - 9s 30ms/step - loss: 0.0344 - accuracy: 0.9871
# Epoch 199/200
# 292/292 [==============================] - 9s 29ms/step - loss: 0.0271 - accuracy: 0.9914
# Epoch 200/200
# 292/292 [==============================] - 10s 33ms/step - loss: 0.0433 - accuracy: 0.9844

# %%
model.save_weights('asian_confusion_weights_final.h5')

# %%
prediction_proba = model.predict(x_test)
y_predict = prediction_proba.argmax(axis=1)
# Out:
# 2024-08-24 00:13:54.745798: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.

# %%
y_predict.shape
# Out:
# (2330,)

# %%
y_true = y_test.argmax(axis=1)

# %%
# confusion matrix
conf_mat = confusion_matrix(y_true, y_predict, normalize='true')

# %%
print(classification_report(y_true, y_predict, target_names=label_names))
# Out:
#               precision    recall  f1-score   support
#
# Not Confused       0.95      0.96      0.96      1263
#     Confused       0.95      0.94      0.95      1067
#
#     accuracy                           0.95      2330
#    macro avg       0.95      0.95      0.95      2330
# weighted avg       0.95      0.95      0.95      2330

# %%
label_names = ['Not Confused', 'Confused']

# %%
fig, ax = plt.subplots(1, 1, figsize=(4, 3))

sns.heatmap(conf_mat, xticklabels= label_names, 
            yticklabels= label_names, annot=True, ax=ax)
fig.savefig('asian_confused_model_performance_all.svg', bbox_inches = 'tight', dpi=300)

# %% [markdown]
# ## if not diagonal, False~
# ## positive or negative depends on references --> is that in the same column, if so positive

# %%
X_train = np.array(x_train_list).reshape(-1, input_dim_, input_dim_, 1)

# %%
# X_train.shape = (5358, 48, 48, 1)
# X_test.shape = (x_test, 48, 48, 1)
# model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=3)

# %%
# load pickle file
with open('Test.pkl', 'rb') as f:
    test_features, test_labels = pickle.load(f)

# %%
x_test_list = []
y_test_list = []
for pic, label in zip(test_features, test_labels):
    # plt.imshow(img_gray, cmap='binary_r')
    x_test_list.append(pic)
    y_test_list.append(label)

# %%
X_test = np.array(x_test_list).reshape(-1, input_dim_, input_dim_, 1)

# %%
X_test.shape
# Out:
# (5376, 128, 128, 1)

# %%
# load pickle file
with open('Validation.pkl', 'rb') as f:
    valid_features, valid_labels = pickle.load(f)

# %%
x_valid_list = []
y_valid_list = []
for pic, label in zip(valid_features, valid_labels):
    # plt.imshow(img_gray, cmap='binary_r')
    x_valid_list.append(pic)
    y_valid_list.append(label)

# %%
X_valid = np.array(x_valid_list).reshape(-1, input_dim_, input_dim_, 1)

# %%
X_valid.shape
# Out:
# (4005, 128, 128, 1)

# %%
df = pd.DataFrame({'y': y_train_list})
sns.countplot(data=df, x='y')
# Out:
# <AxesSubplot: xlabel='y', ylabel='count'>

# %%
df = pd.DataFrame({'y': y_test_list})
sns.countplot(data=df, x='y')
# Out:
# <AxesSubplot: xlabel='y', ylabel='count'>

# %%
df = pd.DataFrame({'y': y_valid_list})
sns.countplot(data=df, x='y')
# Out:
# <AxesSubplot: xlabel='y', ylabel='count'>

# %%
np.array(y_train_list).shape
# Out:
# (15255,)

# %%
from tensorflow.keras.utils import to_categorical
#one-hot encode target column
Y_train = to_categorical(np.array(y_train_list))
Y_test = to_categorical(np.array(y_test_list))
Y_validation = to_categorical(np.array(y_valid_list))
Y_train[200]
# Out:
# array([0., 1., 0., 0.], dtype=float32)

# %%
x_train, x_test, y_train, y_test = train_test_split(X_train, Y_train, test_size=0.2, random_state=42)
x_train.shape, x_test.shape
# Out:
# ((12204, 128, 128, 1), (3051, 128, 128, 1))

# %%
model.fit(x_train, y_train, epochs=30)
# Out:
# Epoch 1/30
# 2024-05-19 21:02:59.502562: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 382/382 [==============================] - 55s 143ms/step - loss: 5.2598 - accuracy: 0.5629
# Epoch 2/30
# 382/382 [==============================] - 51s 134ms/step - loss: 0.6590 - accuracy: 0.7373
# Epoch 3/30
# 382/382 [==============================] - 54s 140ms/step - loss: 0.5048 - accuracy: 0.8017
# Epoch 4/30
#  31/382 [=>............................] - ETA: 56s - loss: 0.3475 - accuracy: 0.8609
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 model.fit(x_train, y_train, epochs=30)
#
# File ~/miniconda/envs/hands/lib/python3.9/site-packages/keras/utils/traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda/envs/hands/lib/python3.9/site-packages/keras/engine/training.py:1409, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1402 with tf.profiler.experimental.Trace(
#    1403     'train',
#    1404     epoch_num=epoch,
#    1405     step_num=step,
#    1406     batch_size=batch_size,
#    1407     _r=1):
#    1408   callbacks.on_train_batch_begin(step)
# -> 1409   tmp_logs = self.train_function(iterator)
#    1410   if data_handler.should_sync:
#    1411     context.async_wait()
#
# File ~/miniconda/envs/hands/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda/envs/hands/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/miniconda/envs/hands/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File ~/miniconda/envs/hands/lib/python3.9/site-packages/tensorflow/python/eager/function.py:2453, in Function.__call__(self, *args, **kwargs)
#    2450 with self._lock:
#    2451   (graph_function,
#    2452    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2453 return graph_function._call_flat(
#    2454     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File ~/miniconda/envs/hands/lib/python3.9/site-packages/tensorflow/python/eager/function.py:1860, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1856 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1857 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1858     and executing_eagerly):
#    1859   # No tape is watching; skip to running the function.
# -> 1860   return self._build_call_outputs(self._inference_function.call(
#    1861       ctx, args, cancellation_manager=cancellation_manager))
#    1862 forward_backward = self._select_forward_and_backward_functions(
#    1863     args,
#    1864     possible_gradient_type,
#    1865     executing_eagerly)
#    1866 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/miniconda/envs/hands/lib/python3.9/site-packages/tensorflow/python/eager/function.py:497, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     495 with _InterpolateFunctionError(self):
#     496   if cancellation_manager is None:
# --> 497     outputs = execute.execute(
#     498         str(self.signature.name),
#     499         num_outputs=self._num_outputs,
#     500         inputs=args,
#     501         attrs=attrs,
#     502         ctx=ctx)
#     503   else:
#     504     outputs = execute.execute_with_cancellation(
#     505         str(self.signature.name),
#     506         num_outputs=self._num_outputs,
#    (...)
#     509         ctx=ctx,
#     510         cancellation_manager=cancellation_manager)
#
# File ~/miniconda/envs/hands/lib/python3.9/site-packages/tensorflow/python/eager/execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_14 (Conv2D)          (None, 124, 124, 64)      1664
#
#  conv2d_15 (Conv2D)          (None, 122, 122, 32)      18464
#
#  flatten_4 (Flatten)         (None, 476288)            0
#
#  dense_9 (Dense)             (None, 4)                 1905156
#
# =================================================================
# Total params: 1,925,284
# Trainable params: 1,925,284
# Non-trainable params: 0
# _________________________________________________________________

# %%
prediction_proba = model.predict(x_test)
y_predict = prediction_proba.argmax(axis=1)
# Out:
#  2/96 [..............................] - ETA: 7s
# 2024-05-19 21:05:49.043001: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 96/96 [==============================] - 2s 24ms/step

# %%
y_predict.shape
# Out:
# (3051,)

# %%
y_true = y_test.argmax(axis=1)

# %%
# y_true = np.array(y_test_list)

# %%
# confusion matrix
conf_mat = confusion_matrix(y_true, y_predict, normalize='true')

# %%
sns.heatmap(conf_mat, annot=True)
# Out:
# <AxesSubplot: >
