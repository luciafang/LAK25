# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Conv2D,
    MaxPooling2D,
    AveragePooling2D,
    Flatten,
    Dense,
    Dropout,
)
import pickle 
import numpy as np
import cv2
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
import pandas as pd
import seaborn as sns
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# Consruct emotion model, download and load weights (Emotion.py in Deepface)

# %%
input_dim_ = 64

# %%
num_classes = 2

model = Sequential()

# 1st convolution layer
model.add(Conv2D(64, (5, 5), activation="relu", input_shape=(input_dim_, input_dim_, 1)))
# model.add(Conv2D(32, (3, 3), activation="relu"))
model.add(MaxPooling2D(pool_size=(5, 5), strides=(2, 2)))

# 2nd convolution layer
# model.add(Conv2D(64, (3, 3), activation="relu"))
# model.add(Conv2D(64, (3, 3), activation="relu"))
# model.add(AveragePooling2D(pool_size=(3, 3), strides=(2, 2)))

# 3rd convolution layer
model.add(Conv2D(128, (3, 3), activation="relu"))
# model.add(Conv2D(128, (3, 3), activation="relu"))
model.add(AveragePooling2D(pool_size=(3, 3), strides=(2, 2)))

model.add(Flatten())

# fully connected neural networks
# model.add(Dense(1024, activation="relu"))
# model.add(Dropout(0.2))
# model.add(Dense(1024, activation="relu"))
# model.add(Dropout(0.2))

model.add(Dense(num_classes, activation="softmax"))
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Metal device set to: Apple M2
# 2024-06-10 00:50:27.546469: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-06-10 00:50:27.546623: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 60, 60, 64)        1664
#
#  max_pooling2d (MaxPooling2D  (None, 28, 28, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 26, 26, 128)       73856
#
#  average_pooling2d (AverageP  (None, 12, 12, 128)      0
#  ooling2D)
#
#  flatten (Flatten)           (None, 18432)             0
#
#  dense (Dense)               (None, 2)                 36866
#
# =================================================================
# Total params: 112,386
# Trainable params: 112,386
# Non-trainable params: 0
# _________________________________________________________________

# %%
# load pickle file
files = ['Polish_Dataset.pkl']
# files = ['Eastern_Asian_Dataset.pkl']
x_train_list = []
y_train_list = [] 
for file in files:
    with open(file, 'rb') as f:
        features, labels = pickle.load(f)
    
    for pic, label in zip(features, labels):
        # plt.imshow(img_gray, cmap='binary_r')
        x_train_list.append(pic)
        y_train_list.append(label)

# %%
X_train = np.array(x_train_list).reshape(-1, input_dim_, input_dim_, 1)
#one-hot encode target column
Y_train = to_categorical(np.array(y_train_list))

# %%
Y_train[500].argmax()
# Out:
# 1

# %%
np.unique(Y_train.argmax(axis=1), return_counts=True)
# Out:
# (array([0, 1]), array([2839, 6888]))

# %%
indices = [np.where(Y_train.argmax(axis=1)==i)[0] for i in np.unique(Y_train.argmax(axis=1))]
indices
# Out:
# [array([1749, 1750, 1751, ..., 8174, 8175, 8176]),
#  array([   0,    1,    2, ..., 9724, 9725, 9726])]

# %%
label_names = ['Not Confused', 'Confused']
rows = 2
cols = 8
# num_to_choose = int(rows*cols)
# np.random.seed(42)
# chosen_nums = np.random.choice(np.arange(len(X_train)), size=num_to_choose, replace=False)
fig, ax = plt.subplots(rows, cols, figsize=(20, 5), sharex=True, sharey=True)

for row in range(rows):
    np.random.seed(35)
    # num_to_choose = int(rows*cols)
    chosen_nums = np.random.choice(indices[row], size=cols, replace=False)
    count = 0
    for col in range(cols):
        ax[row, col].imshow(X_train[chosen_nums[count]], cmap='binary_r')
        ax[row, col].text(32, 10, label_names[Y_train[chosen_nums[count]].argmax()], 
                          horizontalalignment='center', color='r')
        count += 1
        
        ax[row, col].axis('off')

# %%
x_train, x_test, y_train, y_test = train_test_split(X_train, Y_train, test_size=0.2, random_state=42)
# x_train, x_valid, y_train, y_valid = train_test_split(x_train, y_train, test_size=0.25, random_state=42)
x_train.shape, x_test.shape
# Out:
# ((7781, 64, 64, 1), (1946, 64, 64, 1))

# %%
model.fit(x_train, y_train, epochs=200)
# Out:
# 2024-06-10 00:51:08.990748: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# Epoch 1/200
# 2024-06-10 00:51:09.218763: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 244/244 [==============================] - 8s 29ms/step - loss: 1.8925 - accuracy: 0.8608
# Epoch 2/200
# 244/244 [==============================] - 9s 36ms/step - loss: 0.1923 - accuracy: 0.9238
# Epoch 3/200
# 244/244 [==============================] - 9s 38ms/step - loss: 0.1491 - accuracy: 0.9397
# Epoch 4/200
# 244/244 [==============================] - 9s 38ms/step - loss: 0.1735 - accuracy: 0.9360
# Epoch 5/200
# 244/244 [==============================] - 10s 39ms/step - loss: 0.1324 - accuracy: 0.9499
# Epoch 6/200
# 244/244 [==============================] - 10s 41ms/step - loss: 0.1209 - accuracy: 0.9524
# Epoch 7/200
# 244/244 [==============================] - 10s 41ms/step - loss: 0.1123 - accuracy: 0.9571
# Epoch 8/200
# 244/244 [==============================] - 11s 46ms/step - loss: 0.0789 - accuracy: 0.9715
# Epoch 9/200
# 244/244 [==============================] - 12s 48ms/step - loss: 0.0887 - accuracy: 0.9677
# Epoch 10/200
# 244/244 [==============================] - 12s 48ms/step - loss: 0.0896 - accuracy: 0.9676
# Epoch 11/200
# 244/244 [==============================] - 12s 50ms/step - loss: 0.0689 - accuracy: 0.9774
# Epoch 12/200
# 244/244 [==============================] - 12s 48ms/step - loss: 0.0732 - accuracy: 0.9749
# Epoch 13/200
# 244/244 [==============================] - 11s 47ms/step - loss: 0.0728 - accuracy: 0.9734
# Epoch 14/200
# 244/244 [==============================] - 11s 46ms/step - loss: 0.0769 - accuracy: 0.9740
# Epoch 15/200
# 244/244 [==============================] - 11s 46ms/step - loss: 0.0601 - accuracy: 0.9778
# Epoch 16/200
# 244/244 [==============================] - 11s 46ms/step - loss: 0.0658 - accuracy: 0.9775
# Epoch 17/200
# 244/244 [==============================] - 11s 46ms/step - loss: 0.0746 - accuracy: 0.9748
# Epoch 18/200
# 244/244 [==============================] - 10s 42ms/step - loss: 0.0706 - accuracy: 0.9762
# Epoch 19/200
# 244/244 [==============================] - 10s 42ms/step - loss: 0.0575 - accuracy: 0.9797
# Epoch 20/200
# 244/244 [==============================] - 10s 41ms/step - loss: 0.0506 - accuracy: 0.9823
# Epoch 21/200
# 244/244 [==============================] - 10s 41ms/step - loss: 0.0538 - accuracy: 0.9825
# Epoch 22/200
# 244/244 [==============================] - 10s 41ms/step - loss: 0.0523 - accuracy: 0.9814
# Epoch 23/200
# 244/244 [==============================] - 10s 41ms/step - loss: 0.0574 - accuracy: 0.9823
# Epoch 24/200
# 244/244 [==============================] - 10s 41ms/step - loss: 0.0363 - accuracy: 0.9861
# Epoch 25/200
# 244/244 [==============================] - 10s 41ms/step - loss: 0.0349 - accuracy: 0.9889
# Epoch 26/200
# 244/244 [==============================] - 10s 41ms/step - loss: 0.0391 - accuracy: 0.9852
# Epoch 27/200
# 244/244 [==============================] - 10s 41ms/step - loss: 0.0605 - accuracy: 0.9794
# Epoch 28/200
# 244/244 [==============================] - 10s 41ms/step - loss: 0.0418 - accuracy: 0.9864
# Epoch 29/200
# 244/244 [==============================] - 10s 41ms/step - loss: 0.0342 - accuracy: 0.9893
# Epoch 30/200
# 244/244 [==============================] - 10s 41ms/step - loss: 0.0281 - accuracy: 0.9907
# Epoch 31/200
# 244/244 [==============================] - 13s 54ms/step - loss: 0.0518 - accuracy: 0.9842
# Epoch 32/200
# 244/244 [==============================] - 15s 61ms/step - loss: 0.0486 - accuracy: 0.9833
# Epoch 33/200
# 244/244 [==============================] - 12s 49ms/step - loss: 0.0377 - accuracy: 0.9893
# Epoch 34/200
# 244/244 [==============================] - 12s 49ms/step - loss: 0.0357 - accuracy: 0.9887
# Epoch 35/200
# 244/244 [==============================] - 12s 51ms/step - loss: 0.0284 - accuracy: 0.9916
# Epoch 36/200
# 244/244 [==============================] - 12s 49ms/step - loss: 0.0420 - accuracy: 0.9859
# Epoch 37/200
# 244/244 [==============================] - 12s 49ms/step - loss: 0.0223 - accuracy: 0.9925
# Epoch 38/200
# 244/244 [==============================] - 13s 52ms/step - loss: 0.0217 - accuracy: 0.9915
# Epoch 39/200
# 244/244 [==============================] - 13s 53ms/step - loss: 0.0356 - accuracy: 0.9879
# Epoch 40/200
# 244/244 [==============================] - 14s 56ms/step - loss: 0.0529 - accuracy: 0.9862
# Epoch 41/200
# 244/244 [==============================] - 14s 55ms/step - loss: 0.0350 - accuracy: 0.9896
# Epoch 42/200
# 244/244 [==============================] - 13s 55ms/step - loss: 0.0335 - accuracy: 0.9900
# Epoch 43/200
# 244/244 [==============================] - 13s 54ms/step - loss: 0.0258 - accuracy: 0.9920
# Epoch 44/200
# 244/244 [==============================] - 13s 51ms/step - loss: 0.0244 - accuracy: 0.9924
# Epoch 45/200
# 244/244 [==============================] - 13s 52ms/step - loss: 0.0254 - accuracy: 0.9927
# Epoch 46/200
# 244/244 [==============================] - 13s 51ms/step - loss: 0.0194 - accuracy: 0.9932
# Epoch 47/200
# 244/244 [==============================] - 13s 52ms/step - loss: 0.0203 - accuracy: 0.9938
# Epoch 48/200
# 244/244 [==============================] - 13s 52ms/step - loss: 0.0620 - accuracy: 0.9829
# Epoch 49/200
# 244/244 [==============================] - 11s 45ms/step - loss: 0.0322 - accuracy: 0.9891
# Epoch 50/200
# 244/244 [==============================] - 9s 39ms/step - loss: 0.0277 - accuracy: 0.9914
# Epoch 51/200
# 244/244 [==============================] - 9s 37ms/step - loss: 0.0245 - accuracy: 0.9922
# Epoch 52/200
# 244/244 [==============================] - 9s 38ms/step - loss: 0.0226 - accuracy: 0.9933
# Epoch 53/200
# 244/244 [==============================] - 9s 37ms/step - loss: 0.0195 - accuracy: 0.9931
# Epoch 54/200
# 244/244 [==============================] - 10s 40ms/step - loss: 0.0146 - accuracy: 0.9951
# Epoch 55/200
# 244/244 [==============================] - 9s 37ms/step - loss: 0.0237 - accuracy: 0.9923
# Epoch 56/200
# 244/244 [==============================] - 10s 41ms/step - loss: 0.0393 - accuracy: 0.9865
# Epoch 57/200
# 244/244 [==============================] - 9s 39ms/step - loss: 0.0232 - accuracy: 0.9910
# Epoch 58/200
# 244/244 [==============================] - 10s 40ms/step - loss: 0.0198 - accuracy: 0.9931
# Epoch 59/200
# 244/244 [==============================] - 9s 38ms/step - loss: 0.0800 - accuracy: 0.9746
# Epoch 60/200
# 244/244 [==============================] - 9s 37ms/step - loss: 0.0500 - accuracy: 0.9839
# Epoch 61/200
# 244/244 [==============================] - 9s 38ms/step - loss: 0.0249 - accuracy: 0.9915
# Epoch 62/200
# 244/244 [==============================] - 10s 42ms/step - loss: 0.0145 - accuracy: 0.9951
# Epoch 63/200
# 244/244 [==============================] - 9s 37ms/step - loss: 0.0130 - accuracy: 0.9959
# Epoch 64/200
# 244/244 [==============================] - 10s 39ms/step - loss: 0.0123 - accuracy: 0.9967
# Epoch 65/200
# 244/244 [==============================] - 9s 37ms/step - loss: 0.0188 - accuracy: 0.9942
# Epoch 66/200
# 244/244 [==============================] - 9s 37ms/step - loss: 0.0274 - accuracy: 0.9923
# Epoch 67/200
# 244/244 [==============================] - 9s 36ms/step - loss: 0.0160 - accuracy: 0.9942
# Epoch 68/200
# 244/244 [==============================] - 9s 36ms/step - loss: 0.0205 - accuracy: 0.9932
# Epoch 69/200
# 244/244 [==============================] - 9s 36ms/step - loss: 0.0159 - accuracy: 0.9943
# Epoch 70/200
# 244/244 [==============================] - 9s 38ms/step - loss: 0.0099 - accuracy: 0.9970
# Epoch 71/200
# 244/244 [==============================] - 9s 35ms/step - loss: 0.0286 - accuracy: 0.9922
# Epoch 72/200
# 244/244 [==============================] - 9s 35ms/step - loss: 0.0607 - accuracy: 0.9843
# Epoch 73/200
# 244/244 [==============================] - 9s 35ms/step - loss: 0.0181 - accuracy: 0.9941
# Epoch 74/200
# 244/244 [==============================] - 8s 34ms/step - loss: 0.0148 - accuracy: 0.9947
# Epoch 75/200
# 244/244 [==============================] - 8s 35ms/step - loss: 0.0112 - accuracy: 0.9954
# Epoch 76/200
# 244/244 [==============================] - 8s 34ms/step - loss: 0.0119 - accuracy: 0.9963
# Epoch 77/200
# 244/244 [==============================] - 8s 34ms/step - loss: 0.0155 - accuracy: 0.9951
# Epoch 78/200
# 244/244 [==============================] - 9s 35ms/step - loss: 0.0096 - accuracy: 0.9963
# Epoch 79/200
# 244/244 [==============================] - 11s 44ms/step - loss: 0.0114 - accuracy: 0.9955
# Epoch 80/200
# 244/244 [==============================] - 10s 42ms/step - loss: 0.0134 - accuracy: 0.9961
# Epoch 81/200
# 244/244 [==============================] - 10s 41ms/step - loss: 0.0141 - accuracy: 0.9955
# Epoch 82/200
# 244/244 [==============================] - 10s 41ms/step - loss: 0.0233 - accuracy: 0.9925
# Epoch 83/200
# 244/244 [==============================] - 12s 48ms/step - loss: 0.0398 - accuracy: 0.9882
# Epoch 84/200
# 244/244 [==============================] - 13s 50ms/step - loss: 0.0251 - accuracy: 0.9918
# Epoch 85/200
# 244/244 [==============================] - 11s 45ms/step - loss: 0.0303 - accuracy: 0.9896
# Epoch 86/200
# 244/244 [==============================] - 9s 38ms/step - loss: 0.0193 - accuracy: 0.9933
# Epoch 87/200
# 244/244 [==============================] - 9s 37ms/step - loss: 0.0127 - accuracy: 0.9968
# Epoch 88/200
# 244/244 [==============================] - 11s 44ms/step - loss: 0.0083 - accuracy: 0.9967
# Epoch 89/200
# 244/244 [==============================] - 10s 42ms/step - loss: 0.0228 - accuracy: 0.9943
# Epoch 90/200
# 244/244 [==============================] - 9s 35ms/step - loss: 0.0257 - accuracy: 0.9914
# Epoch 91/200
# 244/244 [==============================] - 9s 36ms/step - loss: 0.0267 - accuracy: 0.9922
# Epoch 92/200
# 244/244 [==============================] - 10s 42ms/step - loss: 0.0134 - accuracy: 0.9955
# Epoch 93/200
# 244/244 [==============================] - 9s 38ms/step - loss: 0.0140 - accuracy: 0.9956
# Epoch 94/200
# 244/244 [==============================] - 9s 35ms/step - loss: 0.0154 - accuracy: 0.9949
# Epoch 95/200
# 244/244 [==============================] - 9s 35ms/step - loss: 0.0200 - accuracy: 0.9934
# Epoch 96/200
# 244/244 [==============================] - 8s 34ms/step - loss: 0.0191 - accuracy: 0.9928
# Epoch 97/200
# 244/244 [==============================] - 8s 34ms/step - loss: 0.0100 - accuracy: 0.9967
# Epoch 98/200
# 244/244 [==============================] - 9s 35ms/step - loss: 0.0136 - accuracy: 0.9955
# Epoch 99/200
# 244/244 [==============================] - 10s 41ms/step - loss: 0.0602 - accuracy: 0.9839
# Epoch 100/200
# 244/244 [==============================] - 13s 54ms/step - loss: 0.0297 - accuracy: 0.9910
# Epoch 101/200
# 244/244 [==============================] - 12s 49ms/step - loss: 0.0161 - accuracy: 0.9946
# Epoch 102/200
# 244/244 [==============================] - 11s 44ms/step - loss: 0.0135 - accuracy: 0.9951
# Epoch 103/200
# 244/244 [==============================] - 11s 43ms/step - loss: 0.0140 - accuracy: 0.9947
# Epoch 104/200
# 244/244 [==============================] - 9s 37ms/step - loss: 0.0131 - accuracy: 0.9960
# Epoch 105/200
# 244/244 [==============================] - 10s 41ms/step - loss: 0.0105 - accuracy: 0.9967
# Epoch 106/200
# 244/244 [==============================] - 10s 41ms/step - loss: 0.0102 - accuracy: 0.9967
# Epoch 107/200
# 244/244 [==============================] - 9s 38ms/step - loss: 0.0140 - accuracy: 0.9945
# Epoch 108/200
# 244/244 [==============================] - 9s 36ms/step - loss: 0.0136 - accuracy: 0.9956
# Epoch 109/200
# 244/244 [==============================] - 9s 35ms/step - loss: 0.0155 - accuracy: 0.9946
# Epoch 110/200
# 244/244 [==============================] - 9s 36ms/step - loss: 0.0193 - accuracy: 0.9936
# Epoch 111/200
# 244/244 [==============================] - 13s 55ms/step - loss: 0.0160 - accuracy: 0.9947
# Epoch 112/200
# 244/244 [==============================] - 18s 73ms/step - loss: 0.0185 - accuracy: 0.9940
# Epoch 113/200
# 244/244 [==============================] - 17s 69ms/step - loss: 0.0319 - accuracy: 0.9898
# Epoch 114/200
# 244/244 [==============================] - 14s 56ms/step - loss: 0.0314 - accuracy: 0.9914
# Epoch 115/200
# 244/244 [==============================] - 12s 50ms/step - loss: 0.0285 - accuracy: 0.9916
# Epoch 116/200
# 244/244 [==============================] - 13s 53ms/step - loss: 0.0111 - accuracy: 0.9963
# Epoch 117/200
# 244/244 [==============================] - 12s 51ms/step - loss: 0.0132 - accuracy: 0.9950
# Epoch 118/200
# 244/244 [==============================] - 12s 50ms/step - loss: 0.0128 - accuracy: 0.9958
# Epoch 119/200
# 244/244 [==============================] - 13s 52ms/step - loss: 0.0115 - accuracy: 0.9955
# Epoch 120/200
# 244/244 [==============================] - 12s 51ms/step - loss: 0.0140 - accuracy: 0.9950
# Epoch 121/200
# 244/244 [==============================] - 8s 34ms/step - loss: 0.0423 - accuracy: 0.9868
# Epoch 122/200
# 244/244 [==============================] - 8s 33ms/step - loss: 0.0097 - accuracy: 0.9965
# Epoch 123/200
# 244/244 [==============================] - 8s 33ms/step - loss: 0.0108 - accuracy: 0.9967
# Epoch 124/200
# 244/244 [==============================] - 8s 33ms/step - loss: 0.0160 - accuracy: 0.9945
# Epoch 125/200
# 244/244 [==============================] - 8s 32ms/step - loss: 0.0132 - accuracy: 0.9958
# Epoch 126/200
# 244/244 [==============================] - 8s 32ms/step - loss: 0.0135 - accuracy: 0.9952
# Epoch 127/200
# 244/244 [==============================] - 8s 32ms/step - loss: 0.0142 - accuracy: 0.9959
# Epoch 128/200
# 244/244 [==============================] - 8s 32ms/step - loss: 0.0157 - accuracy: 0.9946
# Epoch 129/200
# 244/244 [==============================] - 8s 33ms/step - loss: 0.0125 - accuracy: 0.9949
# Epoch 130/200
# 244/244 [==============================] - 10s 41ms/step - loss: 0.0100 - accuracy: 0.9963
# Epoch 131/200
# 244/244 [==============================] - 9s 36ms/step - loss: 0.0315 - accuracy: 0.9896
# Epoch 132/200
# 244/244 [==============================] - 13s 51ms/step - loss: 0.0243 - accuracy: 0.9916
# Epoch 133/200
# 244/244 [==============================] - 9s 36ms/step - loss: 0.0185 - accuracy: 0.9956
# Epoch 134/200
# 244/244 [==============================] - 9s 36ms/step - loss: 0.0166 - accuracy: 0.9946
# Epoch 135/200
# 244/244 [==============================] - 9s 36ms/step - loss: 0.0090 - accuracy: 0.9968
# Epoch 136/200
# 244/244 [==============================] - 9s 36ms/step - loss: 0.0079 - accuracy: 0.9969
# Epoch 137/200
# 244/244 [==============================] - 8s 34ms/step - loss: 0.0130 - accuracy: 0.9955
# Epoch 138/200
# 244/244 [==============================] - 8s 34ms/step - loss: 0.0150 - accuracy: 0.9954
# Epoch 139/200
# 244/244 [==============================] - 8s 35ms/step - loss: 0.0169 - accuracy: 0.9945
# Epoch 140/200
# 244/244 [==============================] - 11s 45ms/step - loss: 0.0152 - accuracy: 0.9956
# Epoch 141/200
# 244/244 [==============================] - 11s 45ms/step - loss: 0.0124 - accuracy: 0.9959
# Epoch 142/200
# 244/244 [==============================] - 11s 45ms/step - loss: 0.0111 - accuracy: 0.9960
# Epoch 143/200
# 244/244 [==============================] - 11s 45ms/step - loss: 0.0145 - accuracy: 0.9951
# Epoch 144/200
# 244/244 [==============================] - 11s 45ms/step - loss: 0.0211 - accuracy: 0.9929
# Epoch 145/200
# 244/244 [==============================] - 10s 43ms/step - loss: 0.0108 - accuracy: 0.9952
# Epoch 146/200
# 244/244 [==============================] - 9s 38ms/step - loss: 0.0120 - accuracy: 0.9958
# Epoch 147/200
# 244/244 [==============================] - 9s 37ms/step - loss: 0.0321 - accuracy: 0.9911
# Epoch 148/200
# 244/244 [==============================] - 9s 36ms/step - loss: 0.0152 - accuracy: 0.9952
# Epoch 149/200
# 244/244 [==============================] - 9s 35ms/step - loss: 0.0109 - accuracy: 0.9961
# Epoch 150/200
# 244/244 [==============================] - 11s 47ms/step - loss: 0.0076 - accuracy: 0.9974
# Epoch 151/200
# 244/244 [==============================] - 11s 45ms/step - loss: 0.0115 - accuracy: 0.9959
# Epoch 152/200
# 244/244 [==============================] - 10s 39ms/step - loss: 0.0128 - accuracy: 0.9949
# Epoch 153/200
# 244/244 [==============================] - 10s 41ms/step - loss: 0.0117 - accuracy: 0.9963
# Epoch 154/200
# 244/244 [==============================] - 10s 43ms/step - loss: 0.0158 - accuracy: 0.9949
# Epoch 155/200
# 244/244 [==============================] - 13s 53ms/step - loss: 0.0123 - accuracy: 0.9955
# Epoch 156/200
# 244/244 [==============================] - 13s 54ms/step - loss: 0.0083 - accuracy: 0.9970
# Epoch 157/200
# 244/244 [==============================] - 13s 53ms/step - loss: 0.0180 - accuracy: 0.9946
# Epoch 158/200
# 244/244 [==============================] - 10s 41ms/step - loss: 0.0082 - accuracy: 0.9965
# Epoch 159/200
# 244/244 [==============================] - 9s 39ms/step - loss: 0.0145 - accuracy: 0.9945
# Epoch 160/200
# 244/244 [==============================] - 9s 37ms/step - loss: 0.0108 - accuracy: 0.9960
# Epoch 161/200
# 244/244 [==============================] - 9s 38ms/step - loss: 0.0213 - accuracy: 0.9927
# Epoch 162/200
# 244/244 [==============================] - 9s 39ms/step - loss: 0.0384 - accuracy: 0.9905
# Epoch 163/200
# 244/244 [==============================] - 9s 38ms/step - loss: 0.0117 - accuracy: 0.9958
# Epoch 164/200
# 244/244 [==============================] - 9s 38ms/step - loss: 0.0118 - accuracy: 0.9960
# Epoch 165/200
# 244/244 [==============================] - 9s 38ms/step - loss: 0.0075 - accuracy: 0.9976
# Epoch 166/200
# 244/244 [==============================] - 9s 38ms/step - loss: 0.0067 - accuracy: 0.9969
# Epoch 167/200
# 244/244 [==============================] - 9s 38ms/step - loss: 0.0090 - accuracy: 0.9967
# Epoch 168/200
# 244/244 [==============================] - 9s 39ms/step - loss: 0.0115 - accuracy: 0.9961
# Epoch 169/200
# 244/244 [==============================] - 9s 38ms/step - loss: 0.0110 - accuracy: 0.9959
# Epoch 170/200
# 244/244 [==============================] - 9s 38ms/step - loss: 0.0097 - accuracy: 0.9960
# Epoch 171/200
# 244/244 [==============================] - 9s 38ms/step - loss: 0.0098 - accuracy: 0.9960
# Epoch 172/200
# 244/244 [==============================] - 9s 39ms/step - loss: 0.0089 - accuracy: 0.9970
# Epoch 173/200
# 244/244 [==============================] - 9s 39ms/step - loss: 0.0516 - accuracy: 0.9897
# Epoch 174/200
# 244/244 [==============================] - 9s 38ms/step - loss: 0.0325 - accuracy: 0.9913
# Epoch 175/200
# 244/244 [==============================] - 9s 38ms/step - loss: 0.0152 - accuracy: 0.9961
# Epoch 176/200
# 244/244 [==============================] - 9s 38ms/step - loss: 0.0098 - accuracy: 0.9959
# Epoch 177/200
# 244/244 [==============================] - 9s 39ms/step - loss: 0.0091 - accuracy: 0.9976
# Epoch 178/200
# 244/244 [==============================] - 9s 38ms/step - loss: 0.0095 - accuracy: 0.9968
# Epoch 179/200
# 244/244 [==============================] - 9s 38ms/step - loss: 0.0141 - accuracy: 0.9954
# Epoch 180/200
# 244/244 [==============================] - 10s 39ms/step - loss: 0.0077 - accuracy: 0.9968
# Epoch 181/200
# 244/244 [==============================] - 9s 38ms/step - loss: 0.0074 - accuracy: 0.9969
# Epoch 182/200
# 244/244 [==============================] - 10s 40ms/step - loss: 0.0194 - accuracy: 0.9942
# Epoch 183/200
# 244/244 [==============================] - 10s 39ms/step - loss: 0.0287 - accuracy: 0.9905
# Epoch 184/200
# 244/244 [==============================] - 9s 39ms/step - loss: 0.0155 - accuracy: 0.9960
# Epoch 185/200
# 244/244 [==============================] - 10s 39ms/step - loss: 0.0079 - accuracy: 0.9965
# Epoch 186/200
# 244/244 [==============================] - 10s 39ms/step - loss: 0.0066 - accuracy: 0.9976
# Epoch 187/200
# 244/244 [==============================] - 10s 39ms/step - loss: 0.0068 - accuracy: 0.9967
# Epoch 188/200
# 244/244 [==============================] - 10s 40ms/step - loss: 0.0067 - accuracy: 0.9974
# Epoch 189/200
# 244/244 [==============================] - 10s 40ms/step - loss: 0.0081 - accuracy: 0.9967
# Epoch 190/200
# 244/244 [==============================] - 10s 40ms/step - loss: 0.0075 - accuracy: 0.9972
# Epoch 191/200
# 244/244 [==============================] - 13s 54ms/step - loss: 0.0169 - accuracy: 0.9945
# Epoch 192/200
# 244/244 [==============================] - 16s 64ms/step - loss: 0.0410 - accuracy: 0.9909
# Epoch 193/200
# 244/244 [==============================] - 15s 62ms/step - loss: 0.0084 - accuracy: 0.9972
# Epoch 194/200
# 244/244 [==============================] - 16s 64ms/step - loss: 0.0152 - accuracy: 0.9952
# Epoch 195/200
# 244/244 [==============================] - 16s 65ms/step - loss: 0.0092 - accuracy: 0.9964
# Epoch 196/200
# 244/244 [==============================] - 15s 63ms/step - loss: 0.0075 - accuracy: 0.9972
# Epoch 197/200
# 244/244 [==============================] - 15s 63ms/step - loss: 0.0065 - accuracy: 0.9961
# Epoch 198/200
# 244/244 [==============================] - 12s 49ms/step - loss: 0.0079 - accuracy: 0.9965
# Epoch 199/200
# 244/244 [==============================] - 11s 47ms/step - loss: 0.0081 - accuracy: 0.9967
# Epoch 200/200
# 244/244 [==============================] - 12s 49ms/step - loss: 0.0096 - accuracy: 0.9964

# %%
model.save_weights('polish_confusion_weights.h5')

# %%
prediction_proba = model.predict(x_test)
y_predict = prediction_proba.argmax(axis=1)
# Out:
# 2024-06-10 01:43:53.083501: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.

# %%
y_predict.shape
# Out:
# (1946,)

# %%
y_true = y_test.argmax(axis=1)

# %%
# confusion matrix
conf_mat = confusion_matrix(y_true, y_predict, normalize='true')

# %%
print(classification_report(y_true, y_predict, target_names=label_names))
# Out:
#               precision    recall  f1-score   support
#
# Not Confused       1.00      0.98      0.99       583
#     Confused       0.99      1.00      1.00      1363
#
#     accuracy                           0.99      1946
#    macro avg       0.99      0.99      0.99      1946
# weighted avg       0.99      0.99      0.99      1946

# %%
label_names = ['Not Confused', 'Confused']

# %%
fig, ax = plt.subplots(1, 1, figsize=(4, 3))

sns.heatmap(conf_mat, xticklabels= label_names, 
            yticklabels= label_names, annot=True, ax=ax)
fig.savefig('polish_confused_model_performance_all.svg', bbox_inches = 'tight', dpi=300)

# %% [markdown]
# ## if not diagonal, False~
# ## positive or negative depends on references --> is that in the same column, if so positive

# %%
X_train = np.array(x_train_list).reshape(-1, input_dim_, input_dim_, 1)

# %%
# X_train.shape = (5358, 48, 48, 1)
# X_test.shape = (x_test, 48, 48, 1)
# model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=3)

# %%
# load pickle file
with open('Test.pkl', 'rb') as f:
    test_features, test_labels = pickle.load(f)

# %%
x_test_list = []
y_test_list = []
for pic, label in zip(test_features, test_labels):
    # plt.imshow(img_gray, cmap='binary_r')
    x_test_list.append(pic)
    y_test_list.append(label)

# %%
X_test = np.array(x_test_list).reshape(-1, input_dim_, input_dim_, 1)

# %%
X_test.shape
# Out:
# (5376, 128, 128, 1)

# %%
# load pickle file
with open('Validation.pkl', 'rb') as f:
    valid_features, valid_labels = pickle.load(f)

# %%
x_valid_list = []
y_valid_list = []
for pic, label in zip(valid_features, valid_labels):
    # plt.imshow(img_gray, cmap='binary_r')
    x_valid_list.append(pic)
    y_valid_list.append(label)

# %%
X_valid = np.array(x_valid_list).reshape(-1, input_dim_, input_dim_, 1)

# %%
X_valid.shape
# Out:
# (4005, 128, 128, 1)

# %%
df = pd.DataFrame({'y': y_train_list})
sns.countplot(data=df, x='y')
# Out:
# <AxesSubplot: xlabel='y', ylabel='count'>

# %%
df = pd.DataFrame({'y': y_test_list})
sns.countplot(data=df, x='y')
# Out:
# <AxesSubplot: xlabel='y', ylabel='count'>

# %%
df = pd.DataFrame({'y': y_valid_list})
sns.countplot(data=df, x='y')
# Out:
# <AxesSubplot: xlabel='y', ylabel='count'>

# %%
np.array(y_train_list).shape
# Out:
# (15255,)

# %%
from tensorflow.keras.utils import to_categorical
#one-hot encode target column
Y_train = to_categorical(np.array(y_train_list))
Y_test = to_categorical(np.array(y_test_list))
Y_validation = to_categorical(np.array(y_valid_list))
Y_train[200]
# Out:
# array([0., 1., 0., 0.], dtype=float32)

# %%
x_train, x_test, y_train, y_test = train_test_split(X_train, Y_train, test_size=0.2, random_state=42)
x_train.shape, x_test.shape
# Out:
# ((12204, 128, 128, 1), (3051, 128, 128, 1))

# %%
model.fit(x_train, y_train, epochs=30)
# Out:
# Epoch 1/30
# 2024-05-19 21:02:59.502562: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 382/382 [==============================] - 55s 143ms/step - loss: 5.2598 - accuracy: 0.5629
# Epoch 2/30
# 382/382 [==============================] - 51s 134ms/step - loss: 0.6590 - accuracy: 0.7373
# Epoch 3/30
# 382/382 [==============================] - 54s 140ms/step - loss: 0.5048 - accuracy: 0.8017
# Epoch 4/30
#  31/382 [=>............................] - ETA: 56s - loss: 0.3475 - accuracy: 0.8609
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 model.fit(x_train, y_train, epochs=30)
#
# File ~/miniconda/envs/hands/lib/python3.9/site-packages/keras/utils/traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda/envs/hands/lib/python3.9/site-packages/keras/engine/training.py:1409, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1402 with tf.profiler.experimental.Trace(
#    1403     'train',
#    1404     epoch_num=epoch,
#    1405     step_num=step,
#    1406     batch_size=batch_size,
#    1407     _r=1):
#    1408   callbacks.on_train_batch_begin(step)
# -> 1409   tmp_logs = self.train_function(iterator)
#    1410   if data_handler.should_sync:
#    1411     context.async_wait()
#
# File ~/miniconda/envs/hands/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda/envs/hands/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/miniconda/envs/hands/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File ~/miniconda/envs/hands/lib/python3.9/site-packages/tensorflow/python/eager/function.py:2453, in Function.__call__(self, *args, **kwargs)
#    2450 with self._lock:
#    2451   (graph_function,
#    2452    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2453 return graph_function._call_flat(
#    2454     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File ~/miniconda/envs/hands/lib/python3.9/site-packages/tensorflow/python/eager/function.py:1860, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1856 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1857 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1858     and executing_eagerly):
#    1859   # No tape is watching; skip to running the function.
# -> 1860   return self._build_call_outputs(self._inference_function.call(
#    1861       ctx, args, cancellation_manager=cancellation_manager))
#    1862 forward_backward = self._select_forward_and_backward_functions(
#    1863     args,
#    1864     possible_gradient_type,
#    1865     executing_eagerly)
#    1866 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/miniconda/envs/hands/lib/python3.9/site-packages/tensorflow/python/eager/function.py:497, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     495 with _InterpolateFunctionError(self):
#     496   if cancellation_manager is None:
# --> 497     outputs = execute.execute(
#     498         str(self.signature.name),
#     499         num_outputs=self._num_outputs,
#     500         inputs=args,
#     501         attrs=attrs,
#     502         ctx=ctx)
#     503   else:
#     504     outputs = execute.execute_with_cancellation(
#     505         str(self.signature.name),
#     506         num_outputs=self._num_outputs,
#    (...)
#     509         ctx=ctx,
#     510         cancellation_manager=cancellation_manager)
#
# File ~/miniconda/envs/hands/lib/python3.9/site-packages/tensorflow/python/eager/execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_14 (Conv2D)          (None, 124, 124, 64)      1664
#
#  conv2d_15 (Conv2D)          (None, 122, 122, 32)      18464
#
#  flatten_4 (Flatten)         (None, 476288)            0
#
#  dense_9 (Dense)             (None, 4)                 1905156
#
# =================================================================
# Total params: 1,925,284
# Trainable params: 1,925,284
# Non-trainable params: 0
# _________________________________________________________________

# %%
prediction_proba = model.predict(x_test)
y_predict = prediction_proba.argmax(axis=1)
# Out:
#  2/96 [..............................] - ETA: 7s
# 2024-05-19 21:05:49.043001: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 96/96 [==============================] - 2s 24ms/step

# %%
y_predict.shape
# Out:
# (3051,)

# %%
y_true = y_test.argmax(axis=1)

# %%
# y_true = np.array(y_test_list)

# %%
# confusion matrix
conf_mat = confusion_matrix(y_true, y_predict, normalize='true')

# %%
sns.heatmap(conf_mat, annot=True)
# Out:
# <AxesSubplot: >
